# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

url=input("enter your url")
response=requests.get(url)
print(type(response))
print((response.text))
print(response[0:10001], inplace=True)
# Out:
# enter your urlhttps://www.youtube.com/c/OpeninApp
# <class 'requests.models.Response'>
# ...
